# %% [markdown]
# <a href="https://colab.research.google.com/github/Praewphat/bsc_dpdm22/blob/main/%5Bdataprep1%5D_property_estimator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #สรุปข้อมูลของนักประเมินแต่ละคน โดยพิจารณาจาก ความมั่นใจในการประเมิน ประเมินราคาซื้อ-ขาย ให้คะแนนทรัพย์

# %%
import pandas as pd

# %%
#เชื่อม google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#เข้าไป path ใน google drive
import os
os.chdir('/content/drive/MyDrive/bsc_DPDM_data')

# %%
# !pwd #เช็ค paht ที่กำลังทำงานอยู่
# Out:
# /content/drive/MyDrive/bsc_DPDM_data

# %% [markdown]
# ##บ้าน

# %%
home = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='บ้าน')
home
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
est1 = home[home['ID ผู้ประเมิน']==1]
est1
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 6                1    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 8                1    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 155              1  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 156              1  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 157              1     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 158              1     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 159              1    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
est1.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count          100.0  1.000000e+02         1.000000e+02         0.0
# mean             1.0  4.316360e+06         3.938500e+06         NaN
# std              0.0  2.865391e+06         2.368553e+06         NaN
# min              1.0  3.900000e+05         6.000000e+05         NaN
# 25%              1.0  2.892750e+06         2.775000e+06         NaN
# 50%              1.0  3.962000e+06         3.600000e+06         NaN
# 75%              1.0  5.000000e+06         4.500000e+06         NaN
# max              1.0  2.094900e+07         1.600000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          1.0
# mean           NaN          NaN          NaN        100.0
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN        100.0
# 25%            NaN          NaN          NaN        100.0
# ...

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
from matplotlib import pyplot as plt

# %%
ret1_conf = plt.hist(est1['ความมั่นใจในการเมินราคาทรัพย์'])

# %%
ret1_score = plt.hist(est1['ให้คะแนนทรัพย์'])
plt.xticks(rotation='vertical')
# Out:
# ([0, 1, 2, 3], <a list of 4 Text major ticklabel objects>)

# %%
ret1_score
# Out:
# (array([43.,  0.,  0., 54.,  0.,  0.,  2.,  0.,  0.,  1.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <a list of 10 Patch objects>)

# %%
est1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
est1['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
est1.groupby(['ให้คะแนนทรัพย์']).count()
# Out:
#                                     ID ผู้ประเมิน  post id  property_type  \
# ให้คะแนนทรัพย์
# 1 ขายไม่ได้แน่นอน                               1        1              1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี             54       54             54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน              43       43             43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                2        2              2
#
#                                     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# ให้คะแนนทรัพย์
# 1 ขายไม่ได้แน่นอน                                               1           1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี                             54          54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน                              43          43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน                                2           2
#
#                                     ประเมินราคาซื้อ-ขาย  \
# ให้คะแนนทรัพย์
# 1 ขายไม่ได้แน่นอน                                     1
# ...

# %%
est1[est1['ให้คะแนนทรัพย์']=='2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี'].count()
# Out:
# ID ผู้ประเมิน                     54
# post id                           54
# property_type                     54
# ความมั่นใจในการเมินราคาทรัพย์     54
# ราคาทรัพย์                        54
# ประเมินราคาซื้อ-ขาย               54
# ปัจจัยในการประเมินราคาซื้อ-ขาย    54
# เหตุผลไม่มั่นใจราคาประเมิน         0
# ให้คะแนนทรัพย์                    54
# Unnamed: 9                         0
# Unnamed: 10                        0
# Unnamed: 11                        0
# Unnamed: 12                        0
# Unnamed: 13                        0
# dtype: int64

# %%
est1['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
est2 = home[home['ID ผู้ประเมิน']==2]
print(f'ประเมินทั้งหมด {len(est2)}')
# Out:
# ประเมินทั้งหมด 90

# %%
est2.describe()['ประเมินราคาซื้อ-ขาย']
# Out:
# count    8.900000e+01
# mean     4.153258e+06
# std      2.386901e+06
# min      9.900000e+05
# 25%      2.600000e+06
# 50%      3.900000e+06
# 75%      4.900000e+06
# max      1.700000e+07
# Name: ประเมินราคาซื้อ-ขาย, dtype: float64

# %%
est2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
est2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       89
# ไม่มั่นใจ     1
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %% [markdown]
# ##ที่ดิน

# %%
land = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน')
land
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 1                2   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 2                4   https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 3                1   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 4                2   https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# ..             ...                                    ...           ...
# 205              1  https://nayoo.co/khonkaen/posts/17093        ที่ดิน
# 206              2  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 207              1  https://nayoo.co/khonkaen/posts/17112        ที่ดิน
# 208              2  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
# 209              1  https://nayoo.co/khonkaen/posts/17145        ที่ดิน
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
land['ID ผู้ประเมิน'].value_counts()
# Out:
# 1    100
# 2    100
# 4     10
# Name: ID ผู้ประเมิน, dtype: int64

# %%
est_l1 = land[land['ID ผู้ประเมิน']==1]

# %%
est_l2 = land[land['ID ผู้ประเมิน']==2]

# %% [markdown]
# ##คอนโด

# %%
condo = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='คอนโด')
condo
# Out:
#    ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0              1     32.0         คอนโด                        มั่นใจ
# 1              1     36.0         คอนโด                        มั่นใจ
# 2              1    603.0         คอนโด                        มั่นใจ
# 3              1   1395.0         คอนโด                        มั่นใจ
# 4              1   1443.0         คอนโด                        มั่นใจ
# 5              1   1609.0         คอนโด                        มั่นใจ
# 6              1   1640.0         คอนโด                        มั่นใจ
# 7              1   1641.0         คอนโด                        มั่นใจ
# 8              1   1650.0         คอนโด                        มั่นใจ
# 9              1   1840.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0   3500000.0            3500000.0   60,000-130,000 บาท/ตารางเมตร
# ...

# %%
condo['ID ผู้ประเมิน'].value_counts()
# Out:
# 1    10
# Name: ID ผู้ประเมิน, dtype: int64

# %% [markdown]
# ##ทาวน์โฮม

# %%
tw = pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ทาวน์โฮม')
tw
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 1                2    https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 2                1    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 3                2    https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 4                1    https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# ..             ...                                    ...           ...
# 235              2  https://nayoo.co/khonkaen/posts/18547      ทาวน์โฮม
# 236              2  https://nayoo.co/khonkaen/posts/18551      ทาวน์โฮม
# 237              2  https://nayoo.co/khonkaen/posts/19434      ทาวน์โฮม
# 238              2  https://nayoo.co/khonkaen/posts/19501      ทาวน์โฮม
# 239              2  https://nayoo.co/khonkaen/posts/20367      ทาวน์โฮม
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
tw['ID ผู้ประเมิน'].value_counts()
# Out:
# 1    120
# 2    120
# Name: ID ผู้ประเมิน, dtype: int64

# %%
est_tw1 = tw[tw['ID ผู้ประเมิน']==1]

# %%
est_tw2 =  tw[tw['ID ผู้ประเมิน']==2]

# %% [markdown]
# ##อาคารพาณิชย์

# %%
sh= pd.read_excel('/content/drive/MyDrive/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='อาคารพาณิชย์')
sh
# Out:
#     ID ผู้ประเมิน                              post id          property_type  \
# 0               1    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 1               2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 2               1   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 3               2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 4               1   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 5               2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 6               1   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 7               2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 8               1   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 9               2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
# 10              1   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน
# ...

# %%
sh['ID ผู้ประเมิน'].value_counts()
# Out:
# 1    10
# 2    10
# Name: ID ผู้ประเมิน, dtype: int64

# %%
est_sh1 = sh[sh['ID ผู้ประเมิน']==1]

# %%
est_sh2 = sh[sh['ID ผู้ประเมิน']==2]

# %% [markdown]
# #HW1เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนและของราคาตั้งขาย
#
# ใช้ MAPE เป็นเกณฑ์ในการเปรียบเทียบ
#
# hint เริ่มต้นมาเราอยากได้ตารางรูปแบบนี้ก่อน

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape #mape

# %% [markdown]
# ##บ้าน

# %%
est2['ประเมินโดย 1'] = est2['post id'].map(est1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
est2.head()
# Out:
# <ipython-input-427-9fe03ce6d154>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est2['ประเมินโดย 1'] = est2['post id'].map(est1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#    ID ผู้ประเมิน                              post id property_type  \
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5              2  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7              2  https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9              2  https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                        มั่นใจ   2700000.0            2700000.0
# ...

# %%
est2.rename(columns = {'ประเมินราคาซื้อ-ขาย' : 'ประเมินโดย 2'}, inplace = True) #เปลี่ยนชื่อ
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
all_h = est2[['post id', 'ราคาทรัพย์', 'ประเมินโดย 1', 'ประเมินโดย 2']]
all_h
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0     2500000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0     2200000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0     5000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0     3500000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0     2500000.0
# ..                                     ...         ...           ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0     4500000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0     5200000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0     3600000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0     4000000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0     1200000.0
#
#      ประเมินโดย 2
# 1       2700000.0
# 3       2400000.0
# 5       9000000.0
# 7       3700000.0
# 9       2500000.0
# ..            ...
# ...

# %%
all_h.isnull().any()
# Out:
# post id         False
# ราคาทรัพย์      False
# ประเมินโดย 1    False
# ประเมินโดย 2     True
# dtype: bool

# %%
all_h = all.dropna(subset=['ประเมินโดย 2'])
all_h
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0     2500000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0     2200000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0     5000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0     3500000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0     2500000.0
# ..                                     ...         ...           ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0     4500000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0     5200000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0     3600000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0     4000000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0     1200000.0
#
#      ประเมินโดย 2
# 1       2700000.0
# 3       2400000.0
# 5       9000000.0
# 7       3700000.0
# 9       2500000.0
# ..            ...
# ...

# %%
all_h.isnull().any()
# Out:
# post id         False
# ราคาทรัพย์      False
# ประเมินโดย 1    False
# ประเมินโดย 2    False
# dtype: bool

# %% [markdown]
# ###MAPE ของบ้าน

# %%
actual_h =all_h['ราคาทรัพย์']
pred1_h = all_h['ประเมินโดย 1']
pred2_h = all_h['ประเมินโดย 2']

# %%
mph1 = mape(actual_h,pred1_h)
mph2 = mape(actual_h,pred2_h)
mph12 = mape(pred1_h,pred2_h)
mph21 = mape(pred2_h,pred1_h)

# %%
print(f' MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ {mph1*100:.2f}%\n MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ {mph2*100:.2f}%\n MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ {mph12*100:.2f}%\n MAPE ราคาตั้งขายของผู้ประเมินคนที่ 2 กับ ผู้ประเมินคนที่ 1 คือ {mph21*100:.2f}%')
# Out:
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ 12.32%
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ 10.42%
#  MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ 13.63%
#  MAPE ราคาตั้งขายของผู้ประเมินคนที่ 2 กับ ผู้ประเมินคนที่ 1 คือ 11.58%

# %%
temp = pd.read_excel('คำตอบนักประเมิน.xlsx',sheet_name='บ้าน')
id1 = temp[temp['ID ผู้ประเมิน']==1]
id1 = id1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id2 = temp[temp['ID ผู้ประเมิน']==2]
id2 = id2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
id1MAPE = mape(id1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id1['ราคาทรัพย์']))
id2MAPE = mape(id2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(id2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ\nบ้าน\nนักประเมิน คนที่ 1 = {id1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {id2MAPE*100:.2f}%')
id2['ประเมิน2'] = id2['post id'].map(id1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_d = id2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2two = mape(id2_d['ประเมินราคาซื้อ-ขาย'],id2_d['ประเมิน2'])
two2one = mape(id2_d['ประเมิน2'],id2_d['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2two)+(two2one))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_d)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของ
# บ้าน
# นักประเมิน คนที่ 1 = 13.00%
# นักประเมิน คนที่ 2 = 8.52%
# ความผิดพลาดระหว่างนักประเมินทั้ง 12.60%
# จำนวนทรัพย์ทั้งหมด 89 ทรัพย์

# %% [markdown]
# ##ที่ดิน

# %%
est_l2['ประเมินโดย 1'] = est_l2['post id'].map(est_l1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
est_l2.head()
# Out:
# <ipython-input-437-fa05ff4f8cb8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est_l2['ประเมินโดย 1'] = est_l2['post id'].map(est_l1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
#     ID ผู้ประเมิน                               post id property_type  \
# 1               2  https://nayoo.co/khonkaen/posts/1033        ที่ดิน
# 4               2  https://nayoo.co/khonkaen/posts/1711        ที่ดิน
# 7               2  https://nayoo.co/khonkaen/posts/1726        ที่ดิน
# 10              2  https://nayoo.co/khonkaen/posts/1732        ที่ดิน
# 13              2  https://nayoo.co/khonkaen/posts/1866        ที่ดิน
#
#    ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
est_l2.rename(columns = {'ประเมินราคาซื้อ-ขาย' : 'ประเมินโดย 2'}, inplace = True) #เปลี่ยนชื่อ
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
all_l = est_l2[['post id', 'ราคาทรัพย์', 'ประเมินโดย 1', 'ประเมินโดย 2']]
all_l
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1     https://nayoo.co/khonkaen/posts/1033     2800000     1800000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000     8000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000    18000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000    35000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000     2200000.0
# ..                                     ...         ...           ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000     4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000      500000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000     2000000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000     1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000     2500000.0
#
#      ประเมินโดย 2
# 1       2000000.0
# 4      12000000.0
# 7      70000000.0
# 10     60000000.0
# 13      2500000.0
# ..            ...
# ...

# %%
all_l.isnull().any()
# Out:
# post id         False
# ราคาทรัพย์      False
# ประเมินโดย 1    False
# ประเมินโดย 2    False
# dtype: bool

# %% [markdown]
# ###MAPE ของที่ดิน

# %%
actual_l = all_l['ราคาทรัพย์']
pred1_l = all_l['ประเมินโดย 1']
pred2_l = all_l['ประเมินโดย 2']

# %%
mpl1 = mape(actual_l,pred1_l)
mpl2 = mape(actual_l,pred2_l)
mpl12 = mape(pred1_l,pred2_l)
mpl21 = mape(pred2_l,pred1_l)

# %%
print(f' MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ {mpl1*100:.2f}%\n MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ {mpl2*100:.2f}%\n MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ  {mpl12*100:.2f}%\n MAPEราคาตั้งขายของผู้ประเมินคนที่ 2 กับ ผู้ประเมินคนที่ 1 คือ {mpl21*100:.2f}%')
# Out:
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ 41.34%
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ 40.12%
#  MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ  74.08%
#  MAPEราคาตั้งขายของผู้ประเมินคนที่ 2 กับ ผู้ประเมินคนที่ 1 คือ 42.75%

# %%
temp = pd.read_excel('คำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน')
idl1 = temp[temp['ID ผู้ประเมิน']==1]
idl1 = idl1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idl2 = temp[temp['ID ผู้ประเมิน']==2]
idl2 = idl2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idl1MAPE = mape(idl1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idl1['ราคาทรัพย์']))
idl2MAPE = mape(idl2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idl2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของที่ดิน\nนักประเมิน คนที่ 1 = {idl1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {idl2MAPE*100:.2f}%')
idl2['ประเมิน2'] = idl2['post id'].map(idl1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_l = idl2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2twol = mape(id2_l['ประเมินราคาซื้อ-ขาย'],id2_l['ประเมิน2'])
two2onel = mape(id2_l['ประเมิน2'],id2_l['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2twol)+(two2onel))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_l)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของที่ดิน
# นักประเมิน คนที่ 1 = 83.48%
# นักประเมิน คนที่ 2 = 48.38%
# ความผิดพลาดระหว่างนักประเมินทั้ง 58.41%
# จำนวนทรัพย์ทั้งหมด 100 ทรัพย์

# %% [markdown]
# ##คอนโด

# %%
condo.rename(columns={'ประเมินราคาซื้อ-ขาย' :'ประเมินโดย 1'}, inplace=True)

# %%
all_c = condo[['post id','ราคาทรัพย์','ประเมินโดย 1']]
all_c
# Out:
#    post id  ราคาทรัพย์  ประเมินโดย 1
# 0     32.0   3500000.0     3500000.0
# 1     36.0   1930000.0     2200000.0
# 2    603.0   2438000.0     2800000.0
# 3   1395.0   1600000.0     2300000.0
# 4   1443.0   1860000.0     1800000.0
# 5   1609.0   1490000.0     1500000.0
# 6   1640.0   1280000.0     1600000.0
# 7   1641.0   4290000.0     2700000.0
# 8   1650.0   1700000.0     1550000.0
# 9   1840.0   3790000.0     2800000.0

# %%
all_c.isnull().any()
# Out:
# post id         False
# ราคาทรัพย์      False
# ประเมินโดย 1    False
# dtype: bool

# %% [markdown]
# ###MAPE ของคอนโด

# %%
actual_c = all_c[['ราคาทรัพย์']]
pred1_c = all_c[['ประเมินโดย 1']]

# %%
mc1 = mape(actual_c,pred1_c)

# %%
print(f' MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ {mc1*100:.2f}%')
# Out:
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ 17.35%

# %%
temp = pd.read_excel('คำตอบนักประเมิน.xlsx',sheet_name='คอนโด')
idc1 = temp[temp['ID ผู้ประเมิน']==1]
idc1 = idc1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idc1MAPE = mape(idc1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idc1['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของคอนโด\nนักประเมิน คนที่ 1 = {idc1MAPE*100:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(idc1)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของคอนโด
# นักประเมิน คนที่ 1 = 18.36%
# จำนวนทรัพย์ทั้งหมด 10 ทรัพย์

# %% [markdown]
# ##ทาวน์โฮม

# %%
est_tw2['ประเมินโดย 1'] = est_tw2['post id'].map(est_tw1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
est_tw2.head()
# Out:
# <ipython-input-452-7383a2d7eb1c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est_tw2['ประเมินโดย 1'] = est_tw2['post id'].map(est_tw1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
#    ID ผู้ประเมิน                              post id property_type  \
# 1              2  https://nayoo.co/khonkaen/posts/548      ทาวน์โฮม
# 3              2  https://nayoo.co/khonkaen/posts/549      ทาวน์โฮม
# 5              2  https://nayoo.co/khonkaen/posts/579      ทาวน์โฮม
# 7              2  https://nayoo.co/khonkaen/posts/580      ทาวน์โฮม
# 9              2  https://nayoo.co/khonkaen/posts/582      ทาวน์โฮม
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                        มั่นใจ   1045000.0            1500000.0
# ...

# %%
est_tw2.rename(columns = {'ประเมินราคาซื้อ-ขาย' : 'ประเมินโดย 2'}, inplace = True) #เปลี่ยนชื่อ
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
all_tw = est_tw2[['post id', 'ราคาทรัพย์', 'ประเมินโดย 1', 'ประเมินโดย 2']]
all_tw
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0      700000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0      700000.0
# 5      https://nayoo.co/khonkaen/posts/579   3520000.0     3500000.0
# 7      https://nayoo.co/khonkaen/posts/580   3850000.0     3500000.0
# 9      https://nayoo.co/khonkaen/posts/582    990000.0     1000000.0
# ..                                     ...         ...           ...
# 235  https://nayoo.co/khonkaen/posts/18547   1430000.0     1000000.0
# 236  https://nayoo.co/khonkaen/posts/18551   1980000.0     1500000.0
# 237  https://nayoo.co/khonkaen/posts/19434   2000000.0     1600000.0
# 238  https://nayoo.co/khonkaen/posts/19501   1790000.0     1600000.0
# 239  https://nayoo.co/khonkaen/posts/20367   1590000.0     1700000.0
#
#      ประเมินโดย 2
# 1       1500000.0
# 3       1500000.0
# 5       4000000.0
# 7       3200000.0
# 9        800000.0
# ..            ...
# ...

# %%
all_tw.isnull().any()
# Out:
# post id         False
# ราคาทรัพย์      False
# ประเมินโดย 1    False
# ประเมินโดย 2    False
# dtype: bool

# %% [markdown]
# ###MAPE ของทาวน์โฮม

# %%
actual_tw = all_tw['ราคาทรัพย์']
pred1_tw = all_tw['ประเมินโดย 1']
pred2_tw = all_tw['ประเมินโดย 2']

# %%
mptw1 = mape(actual_tw,pred1_tw)
mptw2 = mape(actual_tw,pred2_tw)
mptw12 = mape(pred1_tw,pred2_tw)
mptw21 = mape(pred2_tw,pred1_tw)

# %%
print(f' MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ {mptw1*100:.2f}%\n MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ {mptw2*100:.2f}%\n MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ {mptw12*100:.2f}%\n MAPE ราคาตั้งขายของผู้ประเมินคนที่ 2 กับ ผู้ประเมินคนที่ 1 คือ {mptw21*100:.2f}%')
# Out:
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ 11.37%
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ 8.77%
#  MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ 11.21%
#  MAPE ราคาตั้งขายของผู้ประเมินคนที่ 2 กับ ผู้ประเมินคนที่ 1 คือ 10.62%

# %%
temp = pd.read_excel('คำตอบนักประเมิน.xlsx',sheet_name='ทาวน์โฮม')
idt1 = temp[temp['ID ผู้ประเมิน']==1]
idt1 = idt1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idt2 = temp[temp['ID ผู้ประเมิน']==2]
idt2 = idt2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idt1MAPE = mape(idt1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idt1['ราคาทรัพย์']))
idt2MAPE = mape(idt2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idt2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของทาวน์โฮม\nนักประเมิน คนที่ 1 = {idt1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {idt2MAPE*100:.2f}%')
idt2['ประเมิน2'] = idt2['post id'].map(idt1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_t = idt2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2twot = mape(id2_t['ประเมินราคาซื้อ-ขาย'],id2_t['ประเมิน2'])
two2onet = mape(id2_t['ประเมิน2'],id2_t['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2twot)+(two2onet))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_t)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของทาวน์โฮม
# นักประเมิน คนที่ 1 = 16.21%
# นักประเมิน คนที่ 2 = 12.75%
# ความผิดพลาดระหว่างนักประเมินทั้ง 10.92%
# จำนวนทรัพย์ทั้งหมด 120 ทรัพย์

# %% [markdown]
# ##อาคารพาณิชย์

# %%
est_sh2['ประเมินโดย 1'] = est_sh2['post id'].map(est_sh1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
est_sh2.head()
# Out:
# <ipython-input-460-bfc5618009b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   est_sh2['ประเมินโดย 1'] = est_sh2['post id'].map(est_sh1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
#    ID ผู้ประเมิน                             post id          property_type  \
# 1              2   https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน
# 3              2  https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน
# 5              2  https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน
# 7              2  https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน
# 9              2  https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
est_sh2.rename(columns = {'ประเมินราคาซื้อ-ขาย' : 'ประเมินโดย 2'}, inplace = True) #เปลี่ยนชื่อ
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
all_sh = est_sh2[['post id', 'ราคาทรัพย์', 'ประเมินโดย 1', 'ประเมินโดย 2']]
all_sh
# Out:
#                                 post id  ราคาทรัพย์  ประเมินโดย 1  \
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0     6000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0    12000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0    13500000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0     4000000.0
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0     2200000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0     3600000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0     2500000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0     3800000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0     7000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0     8000000.0
#
#     ประเมินโดย 2
# 1      8000000.0
# 3     12000000.0
# 5     20000000.0
# 7      4000000.0
# 9      3000000.0
# 11     4000000.0
# 13     2100000.0
# 15     5000000.0
# 17     8000000.0
# 19    10000000.0

# %%
all_sh.isnull().any()
# Out:
# post id         False
# ราคาทรัพย์      False
# ประเมินโดย 1    False
# ประเมินโดย 2    False
# dtype: bool

# %% [markdown]
# ###MAPE ของอาคารพาณิชย์

# %%
actual_sh = all_sh['ราคาทรัพย์']
pred1_sh = all_sh['ประเมินโดย 1']
pred2_sh = all_sh['ประเมินโดย 2']

# %%
mpsh1 = mape(actual_sh,pred1_sh)
mpsh2 = mape(actual_sh,pred2_sh)
mpsh12 = mape(pred1_sh,pred2_sh)
mpsh21 = mape(pred2_sh,pred1_sh)

# %%
print(f' MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ {mpsh1*100:.2f}%\n MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ {mpsh2*100:.2f}%\n MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ {mpsh12*100:.2f}%\n MAPE ราคาตั้งขายของผู้ประเมินคนที่ 2 กับ ผู้ประเมินคนที่ 2 คือ {mpsh21*100:.2f}%')
# Out:
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 1 คือ 17.64%
#  MAPE ราคาทรัพย์กับผู้ประเมินคนที่ 2 คือ 11.73%
#  MAPE ราคาตั้งขายของผู้ประเมินคนที่ 1 กับ ผู้ประเมินคนที่ 2 คือ 21.58%
#  MAPE ราคาตั้งขายของผู้ประเมินคนที่ 2 กับ ผู้ประเมินคนที่ 2 คือ 16.97%

# %%
temp = pd.read_excel('คำตอบนักประเมิน.xlsx',sheet_name='อาคารพาณิชย์')
ids1 = temp[temp['ID ผู้ประเมิน']==1]
ids1 = ids1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
ids2 = temp[temp['ID ผู้ประเมิน']==2]
ids2 = ids2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
ids1MAPE = mape(ids1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(ids1['ราคาทรัพย์']))
ids2MAPE = mape(ids2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(ids2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของอาคารพาณิชย์\nนักประเมิน คนที่ 1 = {ids1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {ids2MAPE*100:.2f}%')
ids2['ประเมิน2'] = ids2['post id'].map(ids1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_s = idt2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2twos = mape(id2_s['ประเมินราคาซื้อ-ขาย'],id2_s['ประเมิน2'])
two2ones = mape(id2_s['ประเมิน2'],id2_s['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2twos)+(two2ones))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_s)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของอาคารพาณิชย์
# นักประเมิน คนที่ 1 = 25.45%
# นักประเมิน คนที่ 2 = 12.43%
# ความผิดพลาดระหว่างนักประเมินทั้ง 10.92%
# จำนวนทรัพย์ทั้งหมด 120 ทรัพย์

# %% [markdown]
# #HW2 แก้ไข ข้อมูลแล้วคำนวณ MAPE ใหม่อีกรอบมาเทียบกัน

# %% [markdown]
# ##เขียน function ตรวจสอบค่าที่เติม 0 ผิด

# %%
max(10,2)
# Out:
# 10

# %%
def check_v(in1,in2):
    return max(in1/in2,in2/in1)

# %%
check_v(100,12)
# Out:
# 8.333333333333334

# %% [markdown]
# ##สร้าง column ใหม่ ลงในตาราง home โดย ค่าใน column คือค่า จาก function check(ราคาตั้งขาย,ราคาประเมิน1)

# %% [markdown]
# ###บ้าน

# %%
all_h['Check1'] = all_h.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']), axis = 1)
all_h['Check2'] = all_h.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 2']), axis = 1)

# %%
all_h.sort_values(by=['Check1'], ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0     3600000.0
# 75       https://nayoo.co/khonkaen/posts/1    390000.0      600000.0
# 177  https://nayoo.co/khonkaen/posts/19450   2100000.0     3200000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0     5200000.0
# 101   https://nayoo.co/khonkaen/posts/6010   2860000.0     4200000.0
# ..                                     ...         ...           ...
# 167   https://nayoo.co/khonkaen/posts/9141   3500000.0     3500000.0
# 51    https://nayoo.co/khonkaen/posts/1149   4000000.0     4000000.0
# 63    https://nayoo.co/khonkaen/posts/2033   1200000.0     1200000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0     4000000.0
# 87    https://nayoo.co/khonkaen/posts/3905   1200000.0     1200000.0
#
#      ประเมินโดย 2    Check1    Check2
# 187     2500000.0  1.800000  1.250000
# 75      1300000.0  1.538462  3.333333
# ...

# %%
all_h.sort_values(by=['Check2'], ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 75       https://nayoo.co/khonkaen/posts/1    390000.0      600000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0     5000000.0
# 111   https://nayoo.co/khonkaen/posts/6045   2915000.0     2000000.0
# 83    https://nayoo.co/khonkaen/posts/3721   3100000.0     3500000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0     3600000.0
# ..                                     ...         ...           ...
# 169  https://nayoo.co/khonkaen/posts/11264   6500000.0     5600000.0
# 69    https://nayoo.co/khonkaen/posts/2262   3200000.0     3300000.0
# 57    https://nayoo.co/khonkaen/posts/1895   1200000.0     1500000.0
# 37     https://nayoo.co/khonkaen/posts/760   1800000.0     1700000.0
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0     2500000.0
#
#      ประเมินโดย 2    Check1    Check2
# 75      1300000.0  1.538462  3.333333
# 5       9000000.0  1.180000  1.525424
# ...

# %% [markdown]
# ####MAPE ของบ้านใหม่

# %%
temp = pd.read_excel('แก้ไขคำตอบนักประเมิน.xlsx',sheet_name='บ้าน')
idl1 = temp[temp['ID ผู้ประเมิน']==1]
idl1 = idl1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idl2 = temp[temp['ID ผู้ประเมิน']==2]
idl2 = idl2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idl1MAPE = mape(idl1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idl1['ราคาทรัพย์']))
idl2MAPE = mape(idl2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idl2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของบ้าน\nนักประเมิน คนที่ 1 = {idl1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {idl2MAPE*100:.2f}%')
idl2['ประเมิน2'] = idl2['post id'].map(idl1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_l = idl2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2twol = mape(id2_l['ประเมินราคาซื้อ-ขาย'],id2_l['ประเมิน2'])
two2onel = mape(id2_l['ประเมิน2'],id2_l['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2twol)+(two2onel))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_l)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของบ้าน
# นักประเมิน คนที่ 1 = 13.75%
# นักประเมิน คนที่ 2 = 9.51%
# ความผิดพลาดระหว่างนักประเมินทั้ง 13.54%
# จำนวนทรัพย์ทั้งหมด 61 ทรัพย์

# %% [markdown]
# ###ที่ดิน

# %%
all_l['Check1'] = all_l.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']), axis = 1)
all_l['Check2'] = all_l.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 2']), axis = 1)
# Out:
# <ipython-input-477-cd2c0097d3b3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_l['Check1'] = all_l.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']), axis = 1)
# <ipython-input-477-cd2c0097d3b3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_l['Check2'] = all_l.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 2']), axis = 1)

# %%
all_l.sort_values(by=['Check1'], ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 194  https://nayoo.co/khonkaen/posts/13702    90000000     4500000.0
# 112   https://nayoo.co/khonkaen/posts/7955     2600000    32000000.0
# 58    https://nayoo.co/khonkaen/posts/9203   160000000    14000000.0
# 47    https://nayoo.co/khonkaen/posts/7349   245000000    24000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000    18000000.0
# ..                                     ...         ...           ...
# 182   https://nayoo.co/khonkaen/posts/9598     3900000     4000000.0
# 78    https://nayoo.co/khonkaen/posts/3447      980000     1000000.0
# 100   https://nayoo.co/khonkaen/posts/1663     1485000     1500000.0
# 122  https://nayoo.co/khonkaen/posts/12762      650000      650000.0
# 130   https://nayoo.co/khonkaen/posts/1599     2500000     2500000.0
#
#      ประเมินโดย 2     Check1     Check2
# 194    75000000.0  20.000000   1.200000
# 112     2000000.0  12.307692   1.300000
# ...

# %%
all_l.sort_values(by=['Check2'], ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 58    https://nayoo.co/khonkaen/posts/9203   160000000    14000000.0
# 47    https://nayoo.co/khonkaen/posts/7349   245000000    24000000.0
# 148   https://nayoo.co/khonkaen/posts/3561     7374550     6000000.0
# 188  https://nayoo.co/khonkaen/posts/12250     2300000     2500000.0
# 144   https://nayoo.co/khonkaen/posts/3341     1700000     1600000.0
# ..                                     ...         ...           ...
# 104   https://nayoo.co/khonkaen/posts/1921     8080000     2800000.0
# 60   https://nayoo.co/khonkaen/posts/12607     7990000    10000000.0
# 158   https://nayoo.co/khonkaen/posts/6732     3500000     2800000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000      500000.0
# 37    https://nayoo.co/khonkaen/posts/3305    14000000    12000000.0
#
#      ประเมินโดย 2     Check1     Check2
# 58     11000000.0  11.428571  14.545455
# 47     18000000.0  10.208333  13.611111
# ...

# %% [markdown]
# ####MAPE ของที่ดินใหม่

# %%
temp = pd.read_excel('แก้ไขคำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน')
idl1 = temp[temp['ID ผู้ประเมิน']==1]
idl1 = idl1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idl2 = temp[temp['ID ผู้ประเมิน']==2]
idl2 = idl2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idl1MAPE = mape(idl1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idl1['ราคาทรัพย์']))
idl2MAPE = mape(idl2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idl2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของที่ดิน\nนักประเมิน คนที่ 1 = {idl1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {idl2MAPE*100:.2f}%')
idl2['ประเมิน2'] = idl2['post id'].map(idl1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_l = idl2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2twol = mape(id2_l['ประเมินราคาซื้อ-ขาย'],id2_l['ประเมิน2'])
two2onel = mape(id2_l['ประเมิน2'],id2_l['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2twol)+(two2onel))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_l)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของที่ดิน
# นักประเมิน คนที่ 1 = 53.94%
# นักประเมิน คนที่ 2 = 25.89%
# ความผิดพลาดระหว่างนักประเมินทั้ง 58.21%
# จำนวนทรัพย์ทั้งหมด 40 ทรัพย์

# %% [markdown]
# ###คอนโด

# %%
all_c['Check1']=ass_c.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)
# Out:
# <ipython-input-484-8b7e9144b8b9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_c['Check1']=ass_c.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)

# %%
all_c.sort_values(by=['Check1'], ascending=False)
# Out:
#    post id  ราคาทรัพย์  ประเมินโดย 1    Check1
# 7   1641.0   4290000.0     2700000.0  1.588889
# 3   1395.0   1600000.0     2300000.0  1.437500
# 9   1840.0   3790000.0     2800000.0  1.353571
# 6   1640.0   1280000.0     1600000.0  1.250000
# 2    603.0   2438000.0     2800000.0  1.148482
# 1     36.0   1930000.0     2200000.0  1.139896
# 8   1650.0   1700000.0     1550000.0  1.096774
# 4   1443.0   1860000.0     1800000.0  1.033333
# 5   1609.0   1490000.0     1500000.0  1.006711
# 0     32.0   3500000.0     3500000.0  1.000000

# %% [markdown]
# ####MAPE ของคอนโดใหม่

# %%
temp = pd.read_excel('แก้ไขคำตอบนักประเมิน.xlsx',sheet_name='คอนโด')
idc1 = temp[temp['ID ผู้ประเมิน']==1]
idc1 = idt1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idc1MAPE = mape(idc1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idc1['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของคอนโด\nนักประเมิน คนที่ 1 = {idc1MAPE*100:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(idc1)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของคอนโด
# นักประเมิน คนที่ 1 = 16.21%
# จำนวนทรัพย์ทั้งหมด 120 ทรัพย์

# %% [markdown]
# ###ทาวน์โฮม

# %%
all_tw['Check1']=all_tw.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)
all_tw['Check2']=all_tw.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 2']),axis=1)
# Out:
# <ipython-input-489-8d5fe3e48645>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tw['Check1']=all_tw.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)
# <ipython-input-489-8d5fe3e48645>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_tw['Check2']=all_tw.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 2']),axis=1)

# %%
all_tw.sort_values(by=['Check1'], ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 176   https://nayoo.co/khonkaen/posts/3528   2190000.0      350000.0
# 180   https://nayoo.co/khonkaen/posts/6095   2420000.0     1500000.0
# 132    https://nayoo.co/khonkaen/posts/619   1430000.0      950000.0
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0      700000.0
# 174   https://nayoo.co/khonkaen/posts/3478   2190000.0     1500000.0
# ..                                     ...         ...           ...
# 228  https://nayoo.co/khonkaen/posts/17923   1990000.0     2000000.0
# 167   https://nayoo.co/khonkaen/posts/2829   2490000.0     2500000.0
# 220  https://nayoo.co/khonkaen/posts/17545   2800000.0     2800000.0
# 200  https://nayoo.co/khonkaen/posts/13411   3200000.0     3200000.0
# 203  https://nayoo.co/khonkaen/posts/17503   1500000.0     1500000.0
#
#      ประเมินโดย 2    Check1    Check2
# 176      400000.0  6.257143  5.475000
# 180     1500000.0  1.613333  1.613333
# ...

# %%
all_tw.sort_values(by=['Check2'], ascending=False)
# Out:
#                                    post id  ราคาทรัพย์  ประเมินโดย 1  \
# 176   https://nayoo.co/khonkaen/posts/3528   2190000.0      350000.0
# 234  https://nayoo.co/khonkaen/posts/18090   3000000.0     2800000.0
# 180   https://nayoo.co/khonkaen/posts/6095   2420000.0     1500000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0      700000.0
# 225  https://nayoo.co/khonkaen/posts/17742   2500000.0     2200000.0
# ..                                     ...         ...           ...
# 188   https://nayoo.co/khonkaen/posts/8101   3200000.0     3300000.0
# 220  https://nayoo.co/khonkaen/posts/17545   2800000.0     2800000.0
# 199  https://nayoo.co/khonkaen/posts/12957   1500000.0     1600000.0
# 151   https://nayoo.co/khonkaen/posts/1978   2500000.0     2700000.0
# 181   https://nayoo.co/khonkaen/posts/6104   2200000.0     2500000.0
#
#      ประเมินโดย 2    Check1    Check2
# 176      400000.0  6.257143  5.475000
# 234     1500000.0  1.071429  2.000000
# ...

# %% [markdown]
# ####MAPE ของทาวน์โฮมใหม่

# %%
temp = pd.read_excel('แก้ไขคำตอบนักประเมิน.xlsx',sheet_name='ทาวน์โฮม')
idt1 = temp[temp['ID ผู้ประเมิน']==1]
idt1 = idt1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idt2 = temp[temp['ID ผู้ประเมิน']==2]
idt2 = idt2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
idt1MAPE = mape(idt1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idt1['ราคาทรัพย์']))
idt2MAPE = mape(idt2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(idt2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของทาวน์โฮม\nนักประเมิน คนที่ 1 = {idt1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {idt2MAPE*100:.2f}%')
idt2['ประเมิน2'] = idt2['post id'].map(idt1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_t = idt2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2twot = mape(id2_t['ประเมินราคาซื้อ-ขาย'],id2_t['ประเมิน2'])
two2onet = mape(id2_t['ประเมิน2'],id2_t['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2twot)+(two2onet))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_t)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของทาวน์โฮม
# นักประเมิน คนที่ 1 = 20.12%
# นักประเมิน คนที่ 2 = 15.84%
# ความผิดพลาดระหว่างนักประเมินทั้ง 11.66%
# จำนวนทรัพย์ทั้งหมด 61 ทรัพย์

# %% [markdown]
# ###อาคารพาณิชย์

# %%
all_sh['Check1']=all_sh.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)
all_sh['Check2']=all_sh.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 2']),axis=1)
# Out:
# <ipython-input-493-1fd9657c9ea9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sh['Check1']=all_sh.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 1']),axis=1)
# <ipython-input-493-1fd9657c9ea9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_sh['Check2']=all_sh.apply(lambda x:check_v(x['ราคาทรัพย์'],x['ประเมินโดย 2']),axis=1)

# %%
all_sh.sort_values(by=['Check1'], ascending=False)
# Out:
#                                 post id  ราคาทรัพย์  ประเมินโดย 1  \
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0     2200000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0    13500000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0     3600000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0     3800000.0
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0     6000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0     4000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0     8000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0     2500000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0    12000000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0     7000000.0
#
#     ประเมินโดย 2    Check1    Check2
# 9      3000000.0  1.772727  1.300000
# 5     20000000.0  1.666667  1.125000
# 11     4000000.0  1.333333  1.200000
# 15     5000000.0  1.315789  1.000000
# 1      8000000.0  1.166667  1.142857
# ...

# %%
all_sh.sort_values(by=['Check2'], ascending=False)
# Out:
#                                 post id  ราคาทรัพย์  ประเมินโดย 1  \
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0     2200000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0     3600000.0
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0     6000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0     4000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0     2500000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0     7000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0    13500000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0     8000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0    12000000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0     3800000.0
#
#     ประเมินโดย 2    Check1    Check2
# 9      3000000.0  1.772727  1.300000
# 11     4000000.0  1.333333  1.200000
# 1      8000000.0  1.166667  1.142857
# 7      4000000.0  1.142857  1.142857
# 13     2100000.0  1.041667  1.142857
# ...

# %% [markdown]
# ####MAPE  ของอาคารพาณิชย์ใหม่

# %%
temp = pd.read_excel('แก้ไขคำตอบนักประเมิน.xlsx',sheet_name='อาคารพาณิชย์')
ids1 = temp[temp['ID ผู้ประเมิน']==1]
ids1 = ids1.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
ids2 = temp[temp['ID ผู้ประเมิน']==2]
ids2 = ids2.dropna(subset=['ราคาทรัพย์','ประเมินราคาซื้อ-ขาย'])
ids1MAPE = mape(ids1['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(ids1['ราคาทรัพย์']))
ids2MAPE = mape(ids2['ประเมินราคาซื้อ-ขาย'],pd.to_numeric(ids2['ราคาทรัพย์']))
print(f'ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของอาคารพาณิชย์\nนักประเมิน คนที่ 1 = {ids1MAPE*100:.2f}%\nนักประเมิน คนที่ 2 = {ids2MAPE*100:.2f}%')
ids2['ประเมิน2'] = ids2['post id'].map(ids1.set_index('post id')['ประเมินราคาซื้อ-ขาย'])
id2_s = idt2.dropna(subset=['ประเมินราคาซื้อ-ขาย','ประเมิน2','ราคาทรัพย์'])
one2twos = mape(id2_s['ประเมินราคาซื้อ-ขาย'],id2_s['ประเมิน2'])
two2ones = mape(id2_s['ประเมิน2'],id2_s['ประเมินราคาซื้อ-ขาย'])
print(f'ความผิดพลาดระหว่างนักประเมินทั้ง {((one2twos)+(two2ones))*50:.2f}%')
print(f'จำนวนทรัพย์ทั้งหมด {len(id2_s)} ทรัพย์')
# Out:
# ความแตกต่างระหว่างราคาประกาศขายและราคาประเมินของอาคารพาณิชย์
# นักประเมิน คนที่ 1 = 25.45%
# นักประเมิน คนที่ 2 = 12.43%
# ความผิดพลาดระหว่างนักประเมินทั้ง 11.66%
# จำนวนทรัพย์ทั้งหมด 61 ทรัพย์
